# %% [markdown]
# ## Enrichment analysis for ELGP

# %%
import pandas as pd
from gseapy import gseaplot
import gseapy as gp
import matplotlib.pyplot as plt

for species in ['mouse','human']:
    ess = pd.read_csv(f"../../data/benchmark/{species}/ess_lnc.csv")
    ess.head()
    gene_sets = {'Essential LncRNA':ess['lncRNA_id']}

    if species == 'human':
        tissue_dict={'heart':'heart left ventricle','lung':'left lung','stomach':'stomach'}
    else:
        tissue_dict={'heart':'heart','lung':'lung','brain':'forebrain'}
    model_names = ['SVM','MLP']

    for model_name in model_names:
        for tissue in tissue_dict.keys():

            tissue_name = tissue_dict[tissue]
            prediction = pd.read_csv(f"../../results/{species}/{model_name}_predictions_{tissue}.csv")
            prediction = prediction[['lncRNA_id','Score']]

            rnk = prediction

            pre_res = gp.prerank(rnk=rnk,
                                gene_sets=gene_sets,
                                threads=4,
                                min_size=5,
                                max_size=4000,
                                permutation_num=1000, # reduce number to speed up testing
                                outdir=None, # don't write to disk
                                seed=6,
                                verbose=True, # see what's going on behind the scenes
                                )

            es_df = pd.DataFrame({
                "lncRNA_id": pre_res.ranking.index,
                "ES_score": pre_res.results['Essential LncRNA']["RES"]
            })
            results = pd.merge(es_df, prediction, on='lncRNA_id', how='inner')
            results['label'] = results['lncRNA_id'].isin(ess['lncRNA_id']).astype(int)
            results.to_csv(f"{species}/res_{model_name}_{tissue}.csv", index=False)
            gsea_res = pre_res.res2d
            gsea_res.to_csv(f"{species}/gsea_{model_name}_{tissue}.csv", index=False)

            terms = pre_res.res2d.Term
            fig = gseaplot(
                term=f"{model_name}({tissue_name})",
                **pre_res.results[terms[0]],
                color="green",
                figsize=(4, 3),
                ofname=f"{species}/{model_name}_{tissue}.svg",
                rank_metric=None
            )
# Out:
# 2025-09-11 15:34:42,355 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:42,409 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:42,410 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:42,410 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:44,903 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:45,166 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:45,201 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:45,202 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:45,203 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:46,699 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:46,957 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:46,994 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:46,996 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:46,996 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:48,533 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:48,746 [WARNING] Duplicated values found in preranked stats: 0.49% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2025-09-11 15:34:48,747 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:48,782 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:48,783 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:48,783 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:50,452 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:50,664 [WARNING] Duplicated values found in preranked stats: 0.05% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2025-09-11 15:34:50,666 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:50,708 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:50,709 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:50,710 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:52,405 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:52,650 [WARNING] Duplicated values found in preranked stats: 0.91% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2025-09-11 15:34:52,652 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:52,691 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:52,692 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:52,693 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:54,349 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:54,588 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:54,646 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:54,648 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:54,648 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:56,931 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:34:57,303 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:34:57,378 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:34:57,381 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:34:57,381 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:34:59,612 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:35:00,003 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:35:00,057 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:35:00,059 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:35:00,060 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:35:02,099 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:35:02,445 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:35:02,505 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:35:02,507 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:35:02,508 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:35:04,688 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:35:05,090 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:35:05,150 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:35:05,152 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:35:05,153 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:35:07,367 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 15:35:07,761 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 15:35:07,828 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 15:35:07,831 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 15:35:07,832 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 15:35:10,398 [INFO] Congratulations. GSEApy runs successfully................

# %% [markdown]
# ## Enrichment analysis for iEssLnc and GIC.

# %%
import pandas as pd
from gseapy import gseaplot
import gseapy as gp
import matplotlib.pyplot as plt

for species in ['human','mouse']:
    ess = pd.read_csv(f"../../data/benchmark/{species}/ess_lnc.csv")
    ess.head()
    gene_sets = {'Essential LncRNA':ess['lncRNA_id']}

    for method in ['GIC','iEssLnc']:

        prediction = pd.read_csv(f"../../results/{species}/{method}_score.csv")
        prediction = prediction[['lncRNA_id','Score']]

        rnk = prediction

        pre_res = gp.prerank(rnk=rnk,
                            gene_sets=gene_sets,
                            threads=4,
                            min_size=5,
                            max_size=4000,
                            permutation_num=1000, # reduce number to speed up testing
                            outdir=None, # don't write to disk
                            seed=6,
                            verbose=True, # see what's going on behind the scenes
                            )

        es_df = pd.DataFrame({
            "lncRNA_id": pre_res.ranking.index,
            "ES_score": pre_res.results['Essential LncRNA']["RES"]
        })
        results = pd.merge(es_df, prediction, on='lncRNA_id', how='inner')
        results['label'] = results['lncRNA_id'].isin(ess['lncRNA_id']).astype(int)
        results.to_csv(f"{species}/res_{method}_{species}.csv", index=False)
        gsea_res = pre_res.res2d
        gsea_res.to_csv(f"{species}/gsea_{method}_{species}.csv", index=False)

        terms = pre_res.res2d.Term
        fig = gseaplot(
            term=f"{method}({species})",
            **pre_res.results[terms[0]],
            color="green",
            figsize=(4, 3),
            ofname=f"{species}/{method}_{species}.svg",
            rank_metric=None
        )
# Out:
# 2025-09-11 19:21:45,308 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2025-09-11 19:21:45,317 [WARNING] Duplicated values found in preranked stats: 4.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2025-09-11 19:21:45,318 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 19:21:45,350 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 19:21:45,351 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 19:21:45,352 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 19:21:47,057 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 19:21:47,345 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 19:21:47,389 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 19:21:47,390 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 19:21:47,391 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 19:21:49,011 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 19:21:50,245 [WARNING] Duplicated values found in preranked stats: 3.40% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2025-09-11 19:21:50,246 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 19:21:50,269 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 19:21:50,270 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 19:21:50,271 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 19:21:51,520 [INFO] Congratulations. GSEApy runs successfully................
#
# 2025-09-11 19:21:51,685 [INFO] Parsing data files for GSEA.............................
# 2025-09-11 19:21:51,725 [INFO] 0000 gene_sets have been filtered out when max_size=4000 and min_size=5
# 2025-09-11 19:21:51,726 [INFO] 0001 gene_sets used for further statistical testing.....
# 2025-09-11 19:21:51,727 [INFO] Start to run GSEA...Might take a while..................
# 2025-09-11 19:21:52,846 [INFO] Congratulations. GSEApy runs successfully................
